# %%
# 1. Import libraries and load dataset 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('heart.csv')

# %%
# 2. Display top 5 rows of dataset 
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %% [markdown]
# * age
# * sex
# * cp (chest pain) (4 values): 0: typical angina  1: atypical angina  2: non-anginal pain  3: asymptomatic
# * trestbps: resting blood pressure (in mm Hg on admission to the hospital)
# * chol: serum cholesterol in mg/dl
# * fbs (fasting blood sugar > 120 mg/dl): 1 = true  0 = false
# * restecg (resting ecg result): 0: normal  1: having ST-T wave abnormality (T wave inversions and /or ST wave elevation or depression of > 0.05mV)
#     2: showing probable or define left ventricular hypertrophy by Estes' criteria
# * thalach: maximum heart rate achieved
# * exang (exercise induced angina): 1 = yes  0 = no
# * oldpeak: St depression induced by exercise relative to rest
# * slope: slope of peak exercise ST segment - 1: unsloping  2: flat  3: downsloping
# * ca: number of major vessels (0-3) coloured by fluoroscopy
# * thal: 3: normal  6: fixed defect  7: reversable defect
# * target: 0: less chance of heart attack  1: more chance of heart attack

# %%
# 3. Check last 5 roes of dataset 
df.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
# 4. Find number of rows and columns of dataset 
print("Shape:", df.shape)
print("Rows:", df.shape[0])
print('Columns:', df.shape[1])
# Out:
# Shape: (1025, 14)
# Rows: 1025
# Columns: 14

# %%
# 5. Get other information about dataset 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
# 6. Check for any null values in dataset 
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
# 7. Check for duplicate values and drop if any 
df.duplicated().sum()
# Out:
# 723

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().any()
# Out:
# False

# %%
# 8. Get overall statistics of the dataset 
df.describe()
# Out:
#              age         sex          cp    trestbps        chol         fbs  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000    0.149007
# std      9.04797    0.466426    1.032044   17.563394   51.753489    0.356686
# min     29.00000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.00000    1.000000    2.000000  140.000000  274.750000    0.000000
# max     77.00000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.526490  149.569536    0.327815    1.043046    1.397351    0.718543
# ...

# %%
# 9. Draw correlation matrix
df.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.094962 -0.063107  0.283121  0.207216  0.119492
# sex      -0.094962  1.000000 -0.051740 -0.057647 -0.195571  0.046022
# cp       -0.063107 -0.051740  1.000000  0.046486 -0.072682  0.096018
# trestbps  0.283121 -0.057647  0.046486  1.000000  0.125256  0.178125
# chol      0.207216 -0.195571 -0.072682  0.125256  1.000000  0.011428
# fbs       0.119492  0.046022  0.096018  0.178125  0.011428  1.000000
# restecg  -0.111590 -0.060351  0.041561 -0.115367 -0.147602 -0.083081
# thalach  -0.395235 -0.046439  0.293367 -0.048023 -0.005308 -0.007169
# exang     0.093216  0.143460 -0.392937  0.068526  0.064099  0.024729
# oldpeak   0.206040  0.098322 -0.146692  0.194600  0.050086  0.004514
# slope    -0.164124 -0.032990  0.116854 -0.122873  0.000417 -0.058654
# ca        0.302261  0.113060 -0.195356  0.099248  0.086878  0.144935
# thal      0.065317  0.211452 -0.160370  0.062870  0.096810 -0.032752
# ...

# %%
plt.figure(figsize=(14,6))
sns.heatmap(data=df.corr(), annot=True)
# Out:
# <Axes: >

# %%
# 10. How many people have heart disease and how many don't have heart disease 
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df['target'].value_counts()
# Out:
# target
# 1    164
# 0    138
# Name: count, dtype: int64

# %%
# 11. Find count of male and female in this dataset 
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df['sex'].value_counts()
# Out:
# sex
# 1    206
# 0     96
# Name: count, dtype: int64

# %%
# 12. Find gender distribution according to the target variable 
sns.countplot(x='sex', data=df, hue='target')
plt.xticks([1,0],['Male', 'Female'])
plt.legend(labels=['No disease', 'Disease'])

# %%
# 13. Check age distribution in the dataset 
sns.displot(df['age'], kde=True)

# %%
# 14. Check chest pain type 
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
plt.figure(figsize=(12,3))
sns.countplot(x=df['cp'], hue=df['cp'])
plt.xticks([0,1,2,3], ['Typical Angina', 'Atypical Angina', 'Non-Anginal Pain', 'Asymptomatic'])
plt.show()

# %%
# 15. Show chest pain distribution as per target variable
plt.figure(figsize=(10,5))
sns.countplot(x='cp', hue='target', data=df)
plt.xticks([0,1,2,3], ['Typical Angina', 'Atypical Angina', 'Non-Anginal Pain', 'Asymptomatic'])
plt.show()

# %%
# 16. Show fasting blood sugar distribution according to target variable
sns.countplot(x='fbs', hue='target', data=df)
plt.xticks([1,0],['Male', 'Female'])
plt.legend(labels=['No disease', 'Disease'])

# %%
# 17. Check resting blood pressure distribution 
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
sns.histplot(df['trestbps'])
# Out:
# <Axes: xlabel='trestbps', ylabel='Count'>

# %%
# 18. Compare resting blood sugar as per sex column 
g = sns.FacetGrid(df, hue='sex', aspect=4)
g.map(sns.kdeplot, 'trestbps', fill=True) # shade= is depricated
plt.legend(labels=['Male', 'Female'])
plt.show()

# %%
# 19. Show distribution of serum cholesterol 
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df['chol'].hist()
# Out:
# <Axes: >

# %%
# 20. Plot continuous variables 
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
cat_col = []
cont_col = []
for col in df.columns: 
    if df[col].nunique() <= 10: 
        cat_col.append(col)
    else: 
        cont_col.append(col)

# %%
cat_col
# Out:
# ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'target']

# %%
cont_col
# Out:
# ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

# %%
df.hist(cont_col, figsize=(15,7))
plt.show()
